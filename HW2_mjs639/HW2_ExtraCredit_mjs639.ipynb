# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import os
from pandas import DataFrame, Series
from datetime import datetime
plt.style.use('seaborn-darkgrid')

# %%
DFdata = os.getenv('DFDATA')
print(DFdata)
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
#df = pd.read_csv(DFdata + "/kwmq-dbub/1414245703/kwmq-dbub")
df = pd.read_csv(DFdata + "/zkky-n5j3/1414246141/zkky-n5j3")

# %%
df.head(5)
# Out:
#    Neversink Date                Neversink Elevation  Neversink Storage  \
# 0  03/01/2005 04:00:00 PM +0000              1440.21              35570
# 1  03/02/2005 04:00:00 PM +0000              1440.22              35575
# 2  03/03/2005 04:00:00 PM +0000              1440.21              35570
# 3  03/04/2005 04:00:00 PM +0000              1440.21              35570
# 4  03/05/2005 04:00:00 PM +0000              1440.21              35570
#
#       Rondout Date               Rondout Elevation  Rondout Storage  \
# 0  03/01/2005 04:00:00 PM +0000             835.10          46757.0
# 1  03/02/2005 04:00:00 PM +0000             834.98          46678.0
# 2  03/03/2005 04:00:00 PM +0000             834.84          46585.0
# 3  03/04/2005 04:00:00 PM +0000             834.85          46592.0
# 4  03/05/2005 04:00:00 PM +0000             834.88          46612.0
#
#     Schoharie Date               Schoharie Elevation  Schoharie Storage  \
# ...

# %%
dfRed = df[df.columns[0:2]]
dfRed = dfRed.rename(columns={'Neversink Date              ': 'NS Date', 'Neversink Elevation': 'NS Elev'})
dfRed['NS Date'] = pd.to_datetime(dfRed['NS Date'])

# %%
dfRed.head(5)
# Out:
#               NS Date  NS Elev
# 0 2005-03-01 16:00:00  1440.21
# 1 2005-03-02 16:00:00  1440.22
# 2 2005-03-03 16:00:00  1440.21
# 3 2005-03-04 16:00:00  1440.21
# 4 2005-03-05 16:00:00  1440.21

# %%
ax = dfRed.plot(x='NS Date', y='NS Elev', style='.', figsize=(15,8),title='Neversink Resevoir Elevation Levels')
ax.set_xlabel("Date")
ax.set_ylabel("Elevation Level")
print("Fig. 1 shows the elevation levels of the Neversink Reservoir over the span of several years")
# Out:
# Fig. 1 shows the elevation levels of the Neversink Reservoir over the span of several years
